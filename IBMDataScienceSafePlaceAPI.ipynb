# %% [markdown]
# <a href="https://colab.research.google.com/github/Utpal-Mishra/Python-Data-Science/blob/main/IBMDataScienceSafePlaceAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import sys
sys.setrecursionlimit(10000)
from tqdm import tqdm

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
#from pandas.io.json import json_normalize
from pandas import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
import random # library for random number generation
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes

import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 

from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

print('Libraries imported.')
# Out:
# Libraries imported.
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
#from pandas.io.json import json_normalize
from pandas import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# # Geolocator: Connaught Place, Delhi, India

# %% [markdown]
# ###Geocode

# %%
address = 'Dublin, Ireland'

geolocator = Nominatim(user_agent="four_square")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Dublin, Ireland are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Dublin, Ireland are 53.3497645, -6.2602732.

# %% [markdown]
# ###Folium: Mapping Connaught Place, Delhi, India

# %%
import folium

Map = folium.Map(location = [latitude, longitude], zoom_start = 14, tiles = 'Stamen Terrain')
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Folium: Mapping Connaught Place, Delhi, India with Marker

# %%
Marker = folium.map.FeatureGroup()

Marker.add_child(folium.CircleMarker([latitude, longitude], 
                                             radius = 5, 
                                             color = 'red', 
                                             fill_color = 'Red'))
Map.add_child(Marker)
folium.Marker([latitude, longitude], popup = 'Dublin').add_to(Map)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #FOURSQAURE

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# ##Account CREDENTIALS

# %%
CLIENT_ID = 'OXWGSYCC0J3EXTWXNULJ3CPAVIVT00YB2U2UR03E3W5H34YM'
CLIENT_SECRET = 'TBRETBUU2J2ZEOKTC0LE5PJ0NDZNBFC2YRB3JMYG5RRIPQM3'
VERSION = '20180604' # Current date

# %% [markdown]
# ##Foursquare URL

# %%
LIMIT = 500
radius = 10000

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, latitude, longitude, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=OXWGSYCC0J3EXTWXNULJ3CPAVIVT00YB2U2UR03E3W5H34YM&client_secret=TBRETBUU2J2ZEOKTC0LE5PJ0NDZNBFC2YRB3JMYG5RRIPQM3&v=20180604&ll=53.3497645,-6.2602732&radius=10000&limit=500'

# %% [markdown]
# ##Sending REQUEST

# %%
result = requests.get(url).json()
result
# Out:
# {'meta': {'code': 200, 'requestId': '5f580fa667b67330497aa7a2'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52dd4d27498ec2361514b507-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'primary': True,
#          'shortName': 'Deli / Bodega'}],
#        'id': '52dd4d27498ec2361514b507',
#        'location': {'address': '147 Parnell St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 407,
#         'formattedAddress': ['147 Parnell St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.35341005820966,
#           'lng': -6.25980695328295}],
#         'lat': 53.35341005820966,
#         'lng': -6.25980695328295,
#         'postalCode': '1',
#         'state': 'Dublin City'},
#        'name': '147 Deli',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f633c67e4b075c711fe625d-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4f633c67e4b075c711fe625d',
#        'location': {'address': '153 Capel St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 612,
#         'formattedAddress': ['153 Capel St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.347137297907544,
#           'lng': -6.2683769070488475}],
#         'lat': 53.347137297907544,
#         'lng': -6.2683769070488475,
#         'postalCode': '1',
#         'state': 'Dublin City'},
#        'name': 'Brother Hubbard North',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '372387939'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-506de70be4b0258b1eb5be71-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '506de70be4b0258b1eb5be71',
#        'location': {'address': 'Crown Alley',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 543,
#         'formattedAddress': ['Crown Alley',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.345127105332885,
#           'lng': -6.262850803298639}],
#         'lat': 53.345127105332885,
#         'lng': -6.262850803298639,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Vintage Cocktail Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58112dc738fafb4f131b4aa5-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '58112dc738fafb4f131b4aa5',
#        'location': {'address': "28-32 O'Connell Street Upper, Dublin 1",
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'crossStreet': 'Cathal Brugha St',
#         'distance': 286,
#         'formattedAddress': ["28-32 O'Connell Street Upper, Dublin 1 (Cathal Brugha St)",
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.3523056,
#           'lng': -6.2609549}],
#         'lat': 53.3523056,
#         'lng': -6.2609549,
#         'postalCode': 'D01 T2X2',
#         'state': 'Dublin City'},
#        'name': 'Holiday Inn Express Dublin City Centre Hotel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-587cfeace612f226c8a3bc1c-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'primary': True,
#          'shortName': 'Donuts'}],
#        'id': '587cfeace612f226c8a3bc1c',
#        'location': {'cc': 'IE',
#         'country': 'Ireland',
#         'distance': 407,
#         'formattedAddress': ['Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34743514947651,
#           'lng': -6.255535131402679}],
#         'lat': 53.34743514947651,
#         'lng': -6.255535131402679},
#        'name': 'Offbeat Donut Co',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-553928b8498e16d131fa2dc8-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'primary': True,
#          'shortName': 'Burgers'}],
#        'id': '553928b8498e16d131fa2dc8',
#        'location': {'address': '22 Essex St E, Temple Bar',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 541,
#         'formattedAddress': ['22 Essex St E, Temple Bar',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.345547472349786,
#           'lng': -6.264330618504215}],
#         'lat': 53.345547472349786,
#         'lng': -6.264330618504215,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Bunsen',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57d8faed498ee3a731e281cf-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '57d8faed498ee3a731e281cf',
#        'location': {'address': '7 Tara Street',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 451,
#         'formattedAddress': ['7 Tara Street',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34714746952024,
#           'lng': -6.255074526485771}],
#         'lat': 53.34714746952024,
#         'lng': -6.255074526485771,
#         'postalCode': 'D02 Y662',
#         'state': 'Dublin City'},
#        'name': 'Shoe Lane Coffee',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '488382902'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af44019f964a520e1f021e3-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'primary': True,
#          'shortName': 'Bookstore'}],
#        'id': '4af44019f964a520e1f021e3',
#        'location': {'address': '56-58 Dawson St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 856,
#         'formattedAddress': ['56-58 Dawson St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34220235099416,
#           'lng': -6.257916902841114}],
#         'lat': 53.34220235099416,
#         'lng': -6.257916902841114,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Hodges Figgis',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ade0f31f964a5206c7121e3-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '4ade0f31f964a5206c7121e3',
#        'location': {'address': '18-19 Parnell Sq',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 554,
#         'formattedAddress': ['18-19 Parnell Sq',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.354248597767295,
#           'lng': -6.263890167284722}],
#         'lat': 53.354248597767295,
#         'lng': -6.263890167284722,
#         'postalCode': '1',
#         'state': 'Dublin City'},
#        'name': 'Chapter One',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c06ce203cbed13a5bd70bc0-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '4c06ce203cbed13a5bd70bc0',
#        'location': {'address': '27 Wicklow St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 756,
#         'formattedAddress': ['27 Wicklow St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34301112406989,
#           'lng': -6.261596115369228}],
#         'lat': 53.34301112406989,
#         'lng': -6.261596115369228,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': "Murphy's Ice Cream",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b91aa44f964a52033ce33e3-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '4b91aa44f964a52033ce33e3',
#        'location': {'address': '15 Mary St Little',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 694,
#         'formattedAddress': ['15 Mary St Little',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34818753089988,
#           'lng': -6.2703793970163035}],
#         'lat': 53.34818753089988,
#         'lng': -6.2703793970163035,
#         'neighborhood': 'North Inner City',
#         'postalCode': '7',
#         'state': 'Dublin City'},
#        'name': 'Hacienda',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af1e047f964a52007e421e3-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '4af1e047f964a52007e421e3',
#        'location': {'address': '16-18 Parliament St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 703,
#         'formattedAddress': ['16-18 Parliament St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.3451586076574,
#           'lng': -6.2675166184520785}],
#         'lat': 53.3451586076574,
#         'lng': -6.2675166184520785,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'The Porterhouse',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-572248a8498e104e054c7476-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'primary': True,
#          'shortName': 'Museum'}],
#        'id': '572248a8498e104e054c7476',
#        'location': {'address': '1 Custom House Quay',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 822,
#         'formattedAddress': ['1 Custom House Quay',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34832258803262,
#           'lng': -6.248130798339844}],
#         'lat': 53.34832258803262,
#         'lng': -6.248130798339844,
#         'neighborhood': 'IFSC, Dublin, Dublin City',
#         'postalCode': 'D01',
#         'state': 'Dublin City'},
#        'name': 'EPIC The Irish Emigration Museum',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '337893817'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54426aa3498e28f66d4b4353-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '54426aa3498e28f66d4b4353',
#        'location': {'address': '20 Anne Street South',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 987,
#         'formattedAddress': ['20 Anne Street South',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.340942,
#           'lng': -6.258772}],
#         'lat': 53.340942,
#         'lng': -6.258772,
#         'neighborhood': 'South-East Inner City',
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Dolce Sicily',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bb9e25e1261d13ae1efe998-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'primary': True,
#          'shortName': 'Apparel'}],
#        'id': '4bb9e25e1261d13ae1efe998',
#        'location': {'address': '22-23 Henry St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 121,
#         'formattedAddress': ['22-23 Henry St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34953336368291,
#           'lng': -6.2620534735637605}],
#         'lat': 53.34953336368291,
#         'lng': -6.2620534735637605,
#         'postalCode': '1',
#         'state': 'Dublin City'},
#        'name': 'Pull&Bear',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f05b6f38b81bb1b02d51f42-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'primary': True,
#          'shortName': 'Sushi'}],
#        'id': '4f05b6f38b81bb1b02d51f42',
#        'location': {'address': '15 Capel St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 608,
#         'formattedAddress': ['15 Capel St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34696817829043,
#           'lng': -6.268146554104451}],
#         'lat': 53.34696817829043,
#         'lng': -6.268146554104451,
#         'postalCode': '1',
#         'state': 'Dublin City'},
#        'name': 'Musashi Noodles & Sushi Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ade0f6df964a520727221e3-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '4ade0f6df964a520727221e3',
#        'location': {'address': '11-17 Exchequer St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 770,
#         'formattedAddress': ['11-17 Exchequer St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.3430738876333,
#           'lng': -6.26323344510237}],
#         'lat': 53.3430738876333,
#         'lng': -6.26323344510237,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Fallon & Byrne Food Store',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ade0f4bf964a520d57121e3-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d17e941735',
#          'name': 'Indie Movie Theater',
#          'pluralName': 'Indie Movie Theaters',
#          'primary': True,
#          'shortName': 'Indie Movies'}],
#        'events': {'count': 1,
#         'items': [{'allDay': True,
#           'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#              'suffix': '.png'},
#             'id': '4dfb90c6bd413dd705e8f897',
#             'name': 'Movie',
#             'pluralName': 'Movies',
#             'primary': True,
#             'shortName': 'Movie'}],
#           'date': 1598396400,
#           'genres': 'Action/Adventure',
#           'id': '5f370c341744057c84cacd91',
#           'images': ['https://playfoursquare.s3.amazonaws.com/events/images/cinemasource/293631h1.jpg'],
#           'name': 'Tenet',
#           'participants': [{'participant': {'displayName': 'Tenet',
#              'id': '5ce71995628c83002cdfd9c9',
#              'images': ['https://playfoursquare.s3.amazonaws.com/events/images/cinemasource/293631h1.jpg',
#               'https://playfoursquare.s3.amazonaws.com/events/images/cinemasource/293631h2.jpg',
#               'https://playfoursquare.s3.amazonaws.com/events/images/cinemasource/293631h3.jpg',
#               'https://playfoursquare.s3.amazonaws.com/events/images/cinemasource/293631h4.jpg',
#               'https://playfoursquare.s3.amazonaws.com/events/images/cinemasource/293631h5.jpg'],
#              'totalEvents': 0},
#             'role': 'movie'}],
#           'rating': 'PG-13',
#           'runningTime': '150',
#           'stats': {'checkinsCount': 1, 'usersCount': 1},
#           'summary': '1:00pm, 4:40pm, 8:10pm',
#           'text': 'Armed with only one word -Tenet- and fighting for the survival of the entire world, the Protagonist journeys through a twilight world of international espionage on a mission that will unfold in something beyond real time. Not time travel - Inversion.',
#           'timeZone': 'Europe/Dublin'}],
#         'summary': 'Tenet'},
#        'id': '4ade0f4bf964a520d57121e3',
#        'location': {'address': '6 Eustace St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 658,
#         'formattedAddress': ['6 Eustace St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.3446669177146,
#           'lng': -6.265294594839052}],
#         'lat': 53.3446669177146,
#         'lng': -6.265294594839052,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Irish Film Institute (IFI)',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '37743330'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b8149e5f964a520c49d30e3-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4b8149e5f964a520c49d30e3',
#        'location': {'address': "Cow's Ln",
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 835,
#         'formattedAddress': ["Cow's Ln", 'Dublin', 'Dublin City', 'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34425548923581,
#           'lng': -6.268803518465996}],
#         'lat': 53.34425548923581,
#         'lng': -6.268803518465996,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Queen of Tarts',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-522dc22f11d24cdd46a86490-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '522dc22f11d24cdd46a86490',
#        'location': {'address': "16 Mary's Abbey, Smithfield",
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 723,
#         'formattedAddress': ["16 Mary's Abbey, Smithfield",
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34705891025317,
#           'lng': -6.270176017790207}],
#         'lat': 53.34705891025317,
#         'lng': -6.270176017790207,
#         'postalCode': '7',
#         'state': 'Dublin City'},
#        'name': 'Oxmantown',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51d185fc498e45cf44c2f0d1-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '51d185fc498e45cf44c2f0d1',
#        'location': {'address': '31 Drury St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 822,
#         'formattedAddress': ['31 Drury St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.342577030893935,
#           'lng': -6.263141509147564}],
#         'lat': 53.342577030893935,
#         'lng': -6.263141509147564,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Kaph',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b890597f964a520951832e3-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1a7941735',
#          'name': 'College Library',
#          'pluralName': 'College Libraries',
#          'primary': True,
#          'shortName': 'Library'}],
#        'id': '4b890597f964a520951832e3',
#        'location': {'address': 'Sean Leabharlann Choláiste na Tríonóide & Taispeántas Leabhar Cheanannais',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 711,
#         'formattedAddress': ['Sean Leabharlann Choláiste na Tríonóide & Taispeántas Leabhar Cheanannais',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34369228474104,
#           'lng': -6.256907495689873}],
#         'lat': 53.34369228474104,
#         'lng': -6.256907495689873,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Trinity College Old Library & The Book of Kells Exhibition',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5bbb42b178782c002baecaf4-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '5bbb42b178782c002baecaf4',
#        'location': {'address': 'Pearse Street',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 796,
#         'formattedAddress': ['Pearse Street', 'Dublin', 'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.344812,
#           'lng': -6.251619}],
#         'lat': 53.344812,
#         'lng': -6.251619,
#         'postalCode': 'DUBLIN 2'},
#        'name': 'Bread 41',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5092a33be4b0eedd3968e593-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#           'suffix': '.png'},
#          'id': '52dea92d3cf9994f4e043dbb',
#          'name': 'Discount Store',
#          'pluralName': 'Discount Stores',
#          'primary': True,
#          'shortName': 'Discount Store'}],
#        'id': '5092a33be4b0eedd3968e593',
#        'location': {'address': '44-45 The Ilac Centre, Moore Street',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'crossStreet': 'Moore St',
#         'distance': 215,
#         'formattedAddress': ['44-45 The Ilac Centre, Moore Street (Moore St)',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.3506228137183,
#           'lng': -6.263183186508172}],
#         'lat': 53.3506228137183,
#         'lng': -6.263183186508172,
#         'postalCode': '1',
#         'state': 'Dublin City'},
#        'name': 'Dealz',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af9f6d2f964a5209b1522e3-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d8941735',
#          'name': 'Gay Bar',
#          'pluralName': 'Gay Bars',
#          'primary': True,
#          'shortName': 'Gay Bar'}],
#        'id': '4af9f6d2f964a5209b1522e3',
#        'location': {'address': '7-8 Capel St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 622,
#         'formattedAddress': ['7-8 Capel St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34651261662103,
#           'lng': -6.267895263804354}],
#         'lat': 53.34651261662103,
#         'lng': -6.267895263804354,
#         'postalCode': '1',
#         'state': 'Dublin City'},
#        'name': 'Pantibar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52c572a0498e003865c5a21d-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'primary': True,
#          'shortName': 'Furniture / Home'}],
#        'id': '52c572a0498e003865c5a21d',
#        'location': {'address': 'Drury St',
#         'cc': 'IE',
#         'city': 'Dublin City',
#         'country': 'Ireland',
#         'distance': 811,
#         'formattedAddress': ['Drury St',
#          'Dublin City',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34266669296261,
#           'lng': -6.263038273302249}],
#         'lat': 53.34266669296261,
#         'lng': -6.263038273302249,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Industry',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e7ca69ab61c9937e5200e4f-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4e7ca69ab61c9937e5200e4f',
#        'location': {'address': '50 S William St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 926,
#         'formattedAddress': ['50 S William St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34158547952957,
#           'lng': -6.262833177740008}],
#         'lat': 53.34158547952957,
#         'lng': -6.262833177740008,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Clement & Pekoe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ade0f17f964a520177121e3-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'primary': True,
#          'shortName': 'Theater'}],
#        'id': '4ade0f17f964a520177121e3',
#        'location': {'address': '26 Lwr Abbey St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 229,
#         'formattedAddress': ['26 Lwr Abbey St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.348541527918414,
#           'lng': -6.257491588986027}],
#         'lat': 53.348541527918414,
#         'lng': -6.257491588986027,
#         'postalCode': '1',
#         'state': 'Dublin City'},
#        'name': 'Abbey Theatre',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af3bcbcf964a52039ef21e3-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4af3bcbcf964a52039ef21e3',
#        'location': {'address': 'Balfe St, Grafton St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 934,
#         'formattedAddress': ['Balfe St, Grafton St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.341394086699125,
#           'lng': -6.261247778318707}],
#         'lat': 53.341394086699125,
#         'lng': -6.261247778318707,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'The Westbury Hotel',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '139497219'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e2fe2858130c05c18cf1650-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '5f2c407c5b4c177b9a6dc536',
#          'name': 'Gelato Shop',
#          'pluralName': 'Gelato Shops',
#          'primary': True,
#          'shortName': 'Gelato'}],
#        'id': '4e2fe2858130c05c18cf1650',
#        'location': {'address': '34B Grafton St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 963,
#         'formattedAddress': ['34B Grafton St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.341109533878964,
#           'lng': -6.260498530182202}],
#         'lat': 53.341109533878964,
#         'lng': -6.260498530182202,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': "Gino's Gelato",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b2750dcf964a520d78524e3-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4b2750dcf964a520d78524e3',
#        'location': {'address': 'Faiche Stiabhna',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 1294,
#         'formattedAddress': ['Faiche Stiabhna',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.338150925581544,
#           'lng': -6.259160041809082}],
#         'lat': 53.338150925581544,
#         'lng': -6.259160041809082,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': "St Stephen's Green",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af480b7f964a5203cf321e3-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'primary': True,
#          'shortName': 'Tapas'}],
#        'id': '4af480b7f964a5203cf321e3',
#        'location': {'address': '64A S William St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 775,
#         'formattedAddress': ['64A S William St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.342885461090326,
#           'lng': -6.262079675075455}],
#         'lat': 53.342885461090326,
#         'lng': -6.262079675075455,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'The Port House',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56bf7a03498ea94e3c044740-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'primary': True,
#          'shortName': 'Burgers'}],
#        'id': '56bf7a03498ea94e3c044740',
#        'location': {'address': '3 South Anne St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 955,
#         'formattedAddress': ['3 South Anne St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.3411781653968,
#           'lng': -6.260036816527849}],
#         'lat': 53.3411781653968,
#         'lng': -6.260036816527849,
#         'state': 'Dublin City'},
#        'name': 'Bunsen',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ade0ef0f964a520817021e3-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '4ade0ef0f964a520817021e3',
#        'location': {'address': '47-48 Temple Bar',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 543,
#         'formattedAddress': ['47-48 Temple Bar',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.3454766557522,
#           'lng': -6.264191652531398}],
#         'lat': 53.3454766557522,
#         'lng': -6.264191652531398,
#         'neighborhood': 'Temple Bar',
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'The Temple Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52835261498eb0c0fc60cb00-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '52835261498eb0c0fc60cb00',
#        'location': {'address': 'Arnotts, Liffey St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 276,
#         'formattedAddress': ['Arnotts, Liffey St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.348833,
#           'lng': -6.264125}],
#         'lat': 53.348833,
#         'lng': -6.264125,
#         'postalCode': '1',
#         'state': 'Dublin City'},
#        'name': "Joe's Coffee",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4eb5a6664901cef9d8a3abfc-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '4eb5a6664901cef9d8a3abfc',
#        'location': {'address': '27 Westmoreland St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 389,
#         'formattedAddress': ['27 Westmoreland St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.346342669382715,
#           'lng': -6.259035112195534}],
#         'lat': 53.346342669382715,
#         'lng': -6.259035112195534,
#         'neighborhood': 'South-East Inner City',
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': "Cassidy's Bar",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-526d4e7011d2fe3ce1e8c1a0-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '526d4e7011d2fe3ce1e8c1a0',
#        'location': {'address': '30 Lwr Stephen St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 985,
#         'formattedAddress': ['30 Lwr Stephen St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34124210282608,
#           'lng': -6.2642640735837665}],
#         'lat': 53.34124210282608,
#         'lng': -6.2642640735837665,
#         'neighborhood': 'South-East Inner City',
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'P. Mac’s',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50506df0e4b030e87ab52f68-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'primary': True,
#          'shortName': 'Vietnamese'}],
#        'id': '50506df0e4b030e87ab52f68',
#        'location': {'address': '46A Capel St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 580,
#         'formattedAddress': ['46A Capel St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.34880076115092,
#           'lng': -6.268863616298785}],
#         'lat': 53.34880076115092,
#         'lng': -6.268863616298785,
#         'postalCode': '1',
#         'state': 'Dublin City'},
#        'name': 'Aobaba',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b081db2f964a5201a0423e3-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d17e941735',
#          'name': 'Indie Movie Theater',
#          'pluralName': 'Indie Movie Theaters',
#          'primary': True,
#          'shortName': 'Indie Movies'}],
#        'events': {'count': 1,
#         'items': [{'allDay': True,
#           'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#              'suffix': '.png'},
#             'id': '4dfb90c6bd413dd705e8f897',
#             'name': 'Movie',
#             'pluralName': 'Movies',
#             'primary': True,
#             'shortName': 'Movie'}],
#           'date': 1599519600,
#           'genres': 'Documentary',
#           'id': '5f3ef59476ab1c3a2fcf77d8',
#           'images': [],
#           'name': "Max Richter's Sleep",
#           'participants': [{'participant': {'displayName': "Max Richter's Sleep",
#              'id': '5e34a4347bc67100079f51b0',
#              'images': [],
# ...
#          'shortName': 'Pub'}],
#        'id': '4b253c21f964a520756e24e3',
#        'location': {'address': '56-57 Lwr Clanbrassil St',
#         'cc': 'IE',
#         'city': 'Dublin 8',
#         'country': 'Ireland',
#         'distance': 2177,
#         'formattedAddress': ['56-57 Lwr Clanbrassil St',
#          'Dublin 8',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.332436,
#           'lng': -6.275473}],
#         'lat': 53.332436,
#         'lng': -6.275473,
#         'postalCode': '8'},
#        'name': '57 The Headline',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '88665659'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af2d5a7f964a520abe821e3-87',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'primary': True,
#          'shortName': 'Breakfast'}],
#        'id': '4af2d5a7f964a520abe821e3',
#        'location': {'address': '9 Hanover Quay',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'crossStreet': 'btwn Forbes St & Asgard Rd',
#         'distance': 1613,
#         'formattedAddress': ['9 Hanover Quay (btwn Forbes St & Asgard Rd)',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.344294,
#           'lng': -6.237792}],
#         'lat': 53.344294,
#         'lng': -6.237792,
#         'postalCode': 'D02 KP20',
#         'state': 'Dublin City'},
#        'name': 'Herbstreet',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ba92deef964a52013123ae3-88',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'primary': True,
#          'shortName': 'Brewery'}],
#        'id': '4ba92deef964a52013123ae3',
#        'location': {'address': "St James's Gate",
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 1964,
#         'formattedAddress': ["St James's Gate",
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.3418895355902,
#           'lng': -6.286733803765022}],
#         'lat': 53.3418895355902,
#         'lng': -6.286733803765022,
#         'postalCode': '8',
#         'state': 'Dublin City'},
#        'name': 'Guinness Storehouse',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5c432a6286bc49002c71807d-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '5c432a6286bc49002c71807d',
#        'location': {'address': '12 South Circular Road',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 2012,
#         'formattedAddress': ['12 South Circular Road', 'Dublin', 'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.332449,
#           'lng': -6.268992}],
#         'lat': 53.332449,
#         'lng': -6.268992,
#         'postalCode': 'DUBLIN 8'},
#        'name': 'Alma',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ba3a0b7f964a5208c4d38e3-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'primary': True,
#          'shortName': 'Bar'}],
#        'id': '4ba3a0b7f964a5208c4d38e3',
#        'location': {'address': "St James's Gate",
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 1975,
#         'formattedAddress': ["St James's Gate",
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.3418007487522,
#           'lng': -6.2868310203070905}],
#         'lat': 53.3418007487522,
#         'lng': -6.2868310203070905,
#         'postalCode': '8',
#         'state': 'Dublin City'},
#        'name': 'Gravity Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5427dc9e498e2d89dfd40c56-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '5427dc9e498e2d89dfd40c56',
#        'location': {'address': '46 Harrington St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 1932,
#         'formattedAddress': ['46 Harrington St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.332681727823996,
#           'lng': -6.265482324880567}],
#         'lat': 53.332681727823996,
#         'lng': -6.265482324880567,
#         'neighborhood': 'South-East Inner City',
#         'state': 'Dublin City'},
#        'name': 'Brother Hubbard South',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55a25ef6498e1d7b38465f54-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'primary': True,
#          'shortName': 'Gourmet'}],
#        'id': '55a25ef6498e1d7b38465f54',
#        'location': {'address': '7 S Lotts Rd',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 2230,
#         'formattedAddress': ['7 S Lotts Rd',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.337662471068384,
#           'lng': -6.233528838007845}],
#         'lat': 53.337662471068384,
#         'lng': -6.233528838007845,
#         'postalCode': 'D04 AC97',
#         'state': 'Dublin City'},
#        'name': 'Lotts & Co',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56e47faf498e68353ce67cf6-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '56e47faf498e68353ce67cf6',
#        'location': {'address': 'Camden St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 1788,
#         'formattedAddress': ['Camden St', 'Dublin', 'Dublin City', 'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.333964970781935,
#           'lng': -6.2651288667132485}],
#         'lat': 53.333964970781935,
#         'lng': -6.2651288667132485,
#         'postalCode': '2',
#         'state': 'Dublin City'},
#        'name': 'Pickle',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b2397b5f964a520065724e3-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4b2397b5f964a520065724e3',
#        'location': {'address': 'Ranelagh',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 2522,
#         'formattedAddress': ['Ranelagh', 'Dublin', 'Dublin City', 'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.32734115320615,
#           'lng': -6.25479498160051}],
#         'lat': 53.32734115320615,
#         'lng': -6.25479498160051,
#         'postalCode': '6',
#         'state': 'Dublin City'},
#        'name': "Nick's Coffee Company",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56bb0d7a498e4d4f218c4fe9-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '56bb0d7a498e4d4f218c4fe9',
#        'location': {'address': '74 Francis St',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 1451,
#         'formattedAddress': ['74 Francis St',
#          'Dublin',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.33933448488834,
#           'lng': -6.273386352695525}],
#         'lat': 53.33933448488834,
#         'lng': -6.273386352695525,
#         'state': 'Dublin City'},
#        'name': 'Two Pups Coffee',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53088d0f11d26d7e933993d2-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '53088d0f11d26d7e933993d2',
#        'location': {'address': 'National Print Museum, Haddington Rd',
#         'cc': 'IE',
#         'country': 'Ireland',
#         'distance': 2332,
#         'formattedAddress': ['National Print Museum, Haddington Rd',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.33505764739972,
#           'lng': -6.235269426252875}],
#         'lat': 53.33505764739972,
#         'lng': -6.235269426252875,
#         'postalCode': '4'},
#        'name': 'Press Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59a140145455b23c829c7b71-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '59a140145455b23c829c7b71',
#        'location': {'address': '40 Drumcondra Rd Lower',
#         'cc': 'IE',
#         'city': 'Dublin',
#         'country': 'Ireland',
#         'distance': 1515,
#         'formattedAddress': ['40 Drumcondra Rd Lower', 'Dublin', 'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.363331,
#           'lng': -6.258335}],
#         'lat': 53.363331,
#         'lng': -6.258335,
#         'neighborhood': 'Drumcondra, Dublin, Dublin City',
#         'postalCode': 'DUBLIN 9'},
#        'name': 'Shouk',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-565df192498e41c6e7136ff3-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '565df192498e41c6e7136ff3',
#        'location': {'address': '1-2 Portobello Rd',
#         'cc': 'IE',
#         'city': 'Portobello',
#         'country': 'Ireland',
#         'distance': 2282,
#         'formattedAddress': ['1-2 Portobello Rd',
#          'Portobello',
#          'Dublin City',
#          'Ireland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53
#
#     venue.location.lng                      venue.location.labeledLatLngs  \
# 0            -6.259807  [{'label': 'display', 'lat': 53.35341005820966...
# 1            -6.268377  [{'label': 'display', 'lat': 53.34713729790754...
# 2            -6.262851  [{'label': 'display', 'lat': 53.34512710533288...
# 3            -6.260955  [{'label': 'display', 'lat': 53.3523056, 'lng'...
# 4            -6.255535  [{'label': 'display', 'lat': 53.34743514947651...
# 5            -6.264331  [{'label': 'display', 'lat': 53.34554747234978...
# 6            -6.255075  [{'label': 'display', 'lat': 53.34714746952024...
# 7            -6.257917  [{'label': 'display', 'lat': 53.34220235099416...
# 8            -6.263890  [{'label': 'display', 'lat': 53.35424859776729...
# 9            -6.261596  [{'label': 'display', 'lat': 53.34301112406989...
# 10           -6.270379  [{'label': 'display', 'lat': 53.34818753089988...
# 11           -6.267517  [{'label': 'display', 'lat': 53.3451586076574,...
# 12           -6.248131  [{'label': 'display', 'lat': 53.34832258803262...
# 13           -6.258772  [{'label': 'display', 'lat': 53.340942, 'lng':...
# 14           -6.262053  [{'label': 'display', 'lat': 53.34953336368291...
# 15           -6.268147  [{'label': 'display', 'lat': 53.34696817829043...
# 16           -6.263233  [{'label': 'display', 'lat': 53.3430738876333,...
# 17           -6.265295  [{'label': 'display', 'lat': 53.3446669177146,...
# 18           -6.268804  [{'label': 'display', 'lat': 53.34425548923581...
# 19           -6.270176  [{'label': 'display', 'lat': 53.34705891025317...
# 20           -6.263142  [{'label': 'display', 'lat': 53.34257703089393...
# 21           -6.256907  [{'label': 'display', 'lat': 53.34369228474104...
# 22           -6.251619  [{'label': 'display', 'lat': 53.344812, 'lng':...
# 23           -6.263183  [{'label': 'display', 'lat': 53.3506228137183,...
# 24           -6.267895  [{'label': 'display', 'lat': 53.34651261662103...
# 25           -6.263038  [{'label': 'display', 'lat': 53.34266669296261...
# 26           -6.262833  [{'label': 'display', 'lat': 53.34158547952957...
# 27           -6.257492  [{'label': 'display', 'lat': 53.34854152791841...
# 28           -6.261248  [{'label': 'display', 'lat': 53.34139408669912...
# 29           -6.260499  [{'label': 'display', 'lat': 53.34110953387896...
# 30           -6.259160  [{'label': 'display', 'lat': 53.33815092558154...
# 31           -6.262080  [{'label': 'display', 'lat': 53.34288546109032...
# 32           -6.260037  [{'label': 'display', 'lat': 53.3411781653968,...
# 33           -6.264192  [{'label': 'display', 'lat': 53.3454766557522,...
# 34           -6.264125  [{'label': 'display', 'lat': 53.348833, 'lng':...
# 35           -6.259035  [{'label': 'display', 'lat': 53.34634266938271...
# 36           -6.264264  [{'label': 'display', 'lat': 53.34124210282608...
# 37           -6.268864  [{'label': 'display', 'lat': 53.34880076115092...
# 38           -6.278976  [{'label': 'display', 'lat': 53.34869068064911...
# 39           -6.266350  [{'label': 'display', 'lat': 53.34542138294974...
# 40           -6.250451  [{'label': 'display', 'lat': 53.34013752866365...
# 41           -6.251253  [{'label': 'display', 'lat': 53.35131966547471...
# 42           -6.254019  [{'label': 'display', 'lat': 53.34207099197960...
# 43           -6.258639  [{'label': 'display', 'lat': 53.34067428271373...
# 44           -6.259588  [{'label': 'display', 'lat': 53.3458349378377,...
# 45           -6.271894  [{'label': 'display', 'lat': 53.34011037061703...
# 46           -6.251014  [{'label': 'display', 'lat': 53.35005943637321...
# 47           -6.267362  [{'label': 'display', 'lat': 53.34216575538019...
# 48           -6.259724  [{'label': 'display', 'lat': 53.34231985828899...
# 49           -6.281092  [{'label': 'display', 'lat': 53.34659185284413...
# 50           -6.258760  [{'label': 'display', 'lat': 53.34105364892371...
# 51           -6.263035  [{'label': 'display', 'lat': 53.34552023801191...
# 52           -6.263057  [{'label': 'display', 'lat': 53.340885, 'lng':...
# 53           -6.250525  [{'label': 'display', 'lat': 53.36052150396311...
# 54           -6.265348  [{'label': 'display', 'lat': 53.34238777245726...
# 55           -6.239362  [{'label': 'display', 'lat': 53.34260914378246...
# 56           -6.258591  [{'label': 'display', 'lat': 53.33985926358760...
# 57           -6.265131  [{'label': 'display', 'lat': 53.33521738452204...
# 58           -6.261059  [{'label': 'display', 'lat': 53.33568033551687...
# 59           -6.283990  [{'label': 'display', 'lat': 53.34992141744724...
# 60           -6.273178  [{'label': 'display', 'lat': 53.35855520732711...
# 61           -6.256014  [{'label': 'display', 'lat': 53.3389725, 'lng'...
# 62           -6.266099  [{'label': 'display', 'lat': 53.33869285474569...
# 63           -6.242132  [{'label': 'display', 'lat': 53.339865, 'lng':...
# 64           -6.269066  [{'label': 'display', 'lat': 53.34970836375576...
# 65           -6.239204  [{'label': 'display', 'lat': 53.344089880104, ...
# 66           -6.253020  [{'label': 'display', 'lat': 53.33857988029337...
# 67           -6.256548  [{'label': 'display', 'lat': 53.34215272618115...
# 68           -6.272902  [{'label': 'display', 'lat': 53.33703902062517...
# 69           -6.263247  [{'label': 'display', 'lat': 53.33526754012723...
# 70           -6.238462  [{'label': 'display', 'lat': 53.34390119383641...
# 71           -6.256618  [{'label': 'display', 'lat': 53.35739, 'lng': ...
# 72           -6.241793  [{'label': 'display', 'lat': 53.34336700958307...
# 73           -6.252528  [{'label': 'display', 'lat': 53.34155790523571...
# 74           -6.278650  [{'label': 'display', 'lat': 53.3487297195115,...
# 75           -6.263497  [{'label': 'display', 'lat': 53.33515227944346...
# 76           -6.272624  [{'label': 'display', 'lat': 53.33355385527208...
# 77           -6.239015  [{'label': 'display', 'lat': 53.34424025976609...
# 78           -6.273716  [{'label': 'display', 'lat': 53.332375, 'lng':...
# 79           -6.281938  [{'label': 'display', 'lat': 53.3473512929815,...
# 80           -6.265517  [{'label': 'display', 'lat': 53.33702640013209...
# 81           -6.264569  [{'label': 'display', 'lat': 53.33120341229505...
# 82           -6.280011  [{'label': 'display', 'lat': 53.34761149061256...
# 83           -6.234691  [{'label': 'display', 'lat': 53.33725976669319...
# 84           -6.274447  [{'label': 'display', 'lat': 53.33444545016298...
# 85           -6.234223  [{'label': 'display', 'lat': 53.33715952435395...
# 86           -6.275473  [{'label': 'display', 'lat': 53.332436, 'lng':...
# 87           -6.237792  [{'label': 'display', 'lat': 53.344294, 'lng':...
# 88           -6.286734  [{'label': 'display', 'lat': 53.3418895355902,...
# 89           -6.268992  [{'label': 'display', 'lat': 53.332449, 'lng':...
# 90           -6.286831  [{'label': 'display', 'lat': 53.3418007487522,...
# 91           -6.265482  [{'label': 'display', 'lat': 53.33268172782399...
# 92           -6.233529  [{'label': 'display', 'lat': 53.33766247106838...
# 93           -6.265129  [{'label': 'display', 'lat': 53.33396497078193...
# 94           -6.254795  [{'label': 'display', 'lat': 53.32734115320615...
# 95           -6.273386  [{'label': 'display', 'lat': 53.33933448488834...
# 96           -6.235269  [{'label': 'display', 'lat': 53.33505764739972...
# 97           -6.258335  [{'label': 'display', 'lat': 53.363331, 'lng':...
# 98           -6.268704  [{'label': 'display', 'lat': 53.32988733435199...
# 99           -6.264804  [{'label': 'display', 'lat': 53.32687089926742...
#
#     venue.location.distance venue.location.postalCode venue.location.cc  \
# 0                       407                         1                IE
# 1                       612                         1                IE
# 2                       543                         2                IE
# 3                       286                  D01 T2X2                IE
# 4                       407                       NaN                IE
# 5                       541                         2                IE
# 6                       451                  D02 Y662                IE
# 7                       856                         2                IE
# 8                       554                         1                IE
# 9                       756                         2                IE
# 10                      694                         7                IE
# 11                      703                         2                IE
# 12                      822                       D01                IE
# 13                      987                         2                IE
# 14                      121                         1                IE
# 15                      608                         1                IE
# 16                      770                         2                IE
# 17                      658                         2                IE
# 18                      835                         2                IE
# 19                      723                         7                IE
# 20                      822                         2                IE
# 21                      711                         2                IE
# 22                      796                  DUBLIN 2                IE
# 23                      215                         1                IE
# 24                      622                         1                IE
# 25                      811                         2                IE
# 26                      926                         2                IE
# 27                      229                         1                IE
# 28                      934                         2                IE
# 29                      963                         2                IE
# 30                     1294                         2                IE
# 31                      775                         2                IE
# 32                      955                       NaN                IE
# 33                      543                         2                IE
# 34                      276                         1                IE
# 35                      389                         2                IE
# 36                      985                         2                IE
# 37                      580                         1                IE
# 38                     1248                         7                IE
# 39                      629                         2                IE
# 40                     1254                         2                IE
# 41                      623                       NaN                IE
# 42                      951                  D02 CY95                IE
# 43                     1017                  DUBLIN 2                IE
# 44                      439                         2                IE
# 45                     1323                         8                IE
# 46                      616                         1                IE
# 47                      968                  D02 AD92                IE
# 48                      829                         2                IE
# 49                     1427                         7                IE
# 50                      974                         2                IE
# 51                      506                         2                IE
# 52                     1005                         2                IE
# 53                     1361                         3                IE
# 54                      887                         2                IE
# 55                     1601                         4                IE
# 56                     1108                         2                IE
# 57                     1651                       NaN                IE
# 58                     1568                         2                IE
# 59                     1576                       NaN                IE
# 60                     1301                       NaN                IE
# 61                     1234                         2                IE
# 62                     1291                         2                IE
# 63                     1633                         2                IE
# 64                      584                         1                IE
# 65                     1536                         2                IE
# 66                     1335                         2                IE
# 67                      882                         2                IE
# 68                     1646                  D08 HFF2                IE
# 69                     1625                         2                IE
# 70                     1589                         2                IE
# 71                      882                  D01 K3T1                IE
# 72                     1419                         2                IE
# 73                     1048                         2                IE
# 74                     1226                       NaN                IE
# 75                     1640                         2                IE
# 76                     1982                         8                IE
# 77                     1540                         2                IE
# 78                     2132                       NaN                IE
# 79                     1464                         7                IE
# 80                     1460                         2                IE
# 81                     2085                         8                IE
# 82                     1333                         7                IE
# 83                     2197                         4                IE
# 84                     1948                         8                IE
# 85                     2228                         4                IE
# 86                     2177                         8                IE
# 87                     1613                  D02 KP20                IE
# 88                     1964                         8                IE
# 89                     2012                  DUBLIN 8                IE
# 90                     1975                         8                IE
# 91                     1932                       NaN                IE
# 92                     2230                  D04 AC97                IE
# 93                     1788                         2                IE
# 94                     2522                         6                IE
# 95                     1451                       NaN                IE
# 96                     2332                         4                IE
# 97                     1515                  DUBLIN 9                IE
# 98                     2282                         8                IE
# 99                     2566                         6                IE
#
#    venue.location.city venue.location.state venue.location.country  \
# 0               Dublin          Dublin City                Ireland
# 1               Dublin          Dublin City                Ireland
# 2               Dublin          Dublin City                Ireland
# 3               Dublin          Dublin City                Ireland
# 4                  NaN                  NaN                Ireland
# 5               Dublin          Dublin City                Ireland
# 6               Dublin          Dublin City                Ireland
# 7               Dublin          Dublin City                Ireland
# 8               Dublin          Dublin City                Ireland
# 9               Dublin          Dublin City                Ireland
# 10              Dublin          Dublin City                Ireland
# 11              Dublin          Dublin City                Ireland
# 12              Dublin          Dublin City                Ireland
# 13              Dublin          Dublin City                Ireland
# 14              Dublin          Dublin City                Ireland
# 15              Dublin          Dublin City                Ireland
# 16              Dublin          Dublin City                Ireland
# 17              Dublin          Dublin City                Ireland
# 18              Dublin          Dublin City                Ireland
# 19              Dublin          Dublin City                Ireland
# 20              Dublin          Dublin City                Ireland
# 21              Dublin          Dublin City                Ireland
# 22              Dublin                  NaN                Ireland
# 23              Dublin          Dublin City                Ireland
# 24              Dublin          Dublin City                Ireland
# 25         Dublin City          Dublin City                Ireland
# 26              Dublin          Dublin City                Ireland
# 27              Dublin          Dublin City                Ireland
# 28              Dublin          Dublin City                Ireland
# 29              Dublin          Dublin City                Ireland
# 30              Dublin          Dublin City                Ireland
# 31              Dublin          Dublin City                Ireland
# 32              Dublin          Dublin City                Ireland
# 33              Dublin          Dublin City                Ireland
# 34              Dublin          Dublin City                Ireland
# 35              Dublin          Dublin City                Ireland
# 36              Dublin          Dublin City                Ireland
# 37              Dublin          Dublin City                Ireland
# 38              Dublin          Dublin City                Ireland
# 39              Dublin          Dublin City                Ireland
# 40              Dublin          Dublin City                Ireland
# 41                 NaN                  NaN                Ireland
# 42              Dublin          Dublin City                Ireland
# 43              Dublin                  NaN                Ireland
# 44              Dublin          Dublin City                Ireland
# 45              Dublin          Dublin City                Ireland
# 46              Dublin          Dublin City                Ireland
# 47              Dublin          Dublin City                Ireland
# 48              Dublin          Dublin City                Ireland
# 49              Dublin          Dublin City                Ireland
# 50              Dublin          Dublin City                Ireland
# 51              Dublin          Dublin City                Ireland
# 52              Dublin          Dublin City                Ireland
# 53              Dublin          Dublin City                Ireland
# 54              Dublin          Dublin City                Ireland
# 55              Dublin          Dublin City                Ireland
# 56              Dublin          Dublin City                Ireland
# 57              Dublin          Dublin City                Ireland
# 58              Dublin          Dublin City                Ireland
[{'id': '4bf58dd8d48988d146941735', 'name': 'D...
# 1  Dublin  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...
# 2  Dublin  [{'id': '4bf58dd8d48988d11e941735', 'name': 'C...
# 3  Dublin  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# 4     NaN  [{'id': '4bf58dd8d48988d148941735', 'name': 'D...

# %%
data['Categories'] = data['Categories'].apply(lambda x: x[0]['name'])
data.head()
# Out:
#                                            Name  \
# 0                                      147 Deli
# 1                         Brother Hubbard North
# 2                         Vintage Cocktail Club
# 3  Holiday Inn Express Dublin City Centre Hotel
# 4                              Offbeat Donut Co
#
#                                   Address   Latitude  Longitude  Distance  \
# 0                          147 Parnell St  53.353410  -6.259807       407
# 1                            153 Capel St  53.347137  -6.268377       612
# 2                             Crown Alley  53.345127  -6.262851       543
# 3  28-32 O'Connell Street Upper, Dublin 1  53.352306  -6.260955       286
# 4                                     NaN  53.347435  -6.255535       407
#
#      City     Categories
# 0  Dublin  Deli / Bodega
# 1  Dublin           Café
# 2  Dublin   Cocktail Bar
# 3  Dublin          Hotel
# 4     NaN     Donut Shop

# %%
data = data[['Name', 'Categories', 'Distance', 'Address', 'City', 'Latitude', 'Longitude']]
data.head(10)
# Out:
#                                            Name      Categories  Distance  \
# 0                                      147 Deli   Deli / Bodega       407
# 1                         Brother Hubbard North            Café       612
# 2                         Vintage Cocktail Club    Cocktail Bar       543
# 3  Holiday Inn Express Dublin City Centre Hotel           Hotel       286
# 4                              Offbeat Donut Co      Donut Shop       407
# 5                                        Bunsen    Burger Joint       541
# 6                              Shoe Lane Coffee            Café       451
# 7                                 Hodges Figgis       Bookstore       856
# 8                                   Chapter One      Restaurant       554
# 9                            Murphy's Ice Cream  Ice Cream Shop       756
#
#                                   Address    City   Latitude  Longitude
# 0                          147 Parnell St  Dublin  53.353410  -6.259807
# 1                            153 Capel St  Dublin  53.347137  -6.268377
# 2                             Crown Alley  Dublin  53.345127  -6.262851
# 3  28-32 O'Connell Street Upper, Dublin 1  Dublin  53.352306  -6.260955
# 4                                     NaN     NaN  53.347435  -6.255535
# 5               22 Essex St E, Temple Bar  Dublin  53.345547  -6.264331
# 6                           7 Tara Street  Dublin  53.347147  -6.255075
# 7                         56-58 Dawson St  Dublin  53.342202  -6.257917
# 8                        18-19 Parnell Sq  Dublin  53.354249  -6.263890
# 9                           27 Wicklow St  Dublin  53.343011  -6.261596

# %% [markdown]
# ###Sorting DATAFRAME

# %%
data.sort_values(by = ['Distance'])
# Out:
#                                                  Name  \
# 14                                          Pull&Bear
# 23                                              Dealz
# 27                                      Abbey Theatre
# 34                                       Joe's Coffee
# 3        Holiday Inn Express Dublin City Centre Hotel
# 35                                      Cassidy's Bar
# 0                                            147 Deli
# 4                                    Offbeat Donut Co
# 44                                     The Palace Bar
# 6                                    Shoe Lane Coffee
# 51                                  Temple Bar Square
# 5                                              Bunsen
# 2                               Vintage Cocktail Club
# 33                                     The Temple Bar
# 8                                         Chapter One
# 37                                             Aobaba
# 64                                    The Black Sheep
# 15                        Musashi Noodles & Sushi Bar
# 1                               Brother Hubbard North
# 46                                      The Brew Dock
# 24                                           Pantibar
# 41                                     Laine, my love
# 57                                   20 Camden Street       Dublin  53.335217
# 93                                          Camden St       Dublin  53.333965
# 91                                   46 Harrington St       Dublin  53.332682
# 84                                 Clanbrassil St Lwr       Dublin  53.334445
# 88                                    St James's Gate       Dublin  53.341890
# 90                                    St James's Gate       Dublin  53.341801
# 76                                  14B Emorville Ave       Dublin  53.333554
# 89                             12 South Circular Road       Dublin  53.332449
# 81                                   45 Richmond St S       Dublin  53.331203
# 78                               82 South Circular Rd          NaN  53.332375
# 86                           56-57 Lwr Clanbrassil St     Dublin 8  53.332436
# 83                             58 Uppr Grand Canal St       Dublin  53.337260
# 85                                         2 Bath Ave       Dublin  53.337160
# 92                                       7 S Lotts Rd       Dublin  53.337662
# 98                                  1-2 Portobello Rd   Portobello  53.329887
# 96               National Print Museum, Haddington Rd          NaN  53.335058
# 94                                           Ranelagh       Dublin  53.327341
# 99                                   Rathmines Rd Lwr       Dublin  53.326871
#
#     Longitude
# 14  -6.262053
# 23  -6.263183
# 27  -6.257492
# 34  -6.264125
# 3   -6.260955
# 35  -6.259035
# 0   -6.259807
# 4   -6.255535
# 44  -6.259588
# 6   -6.255075
# 51  -6.263035
# 5   -6.264331
# 2   -6.262851
# 33  -6.264192
# 8   -6.263890
# 37  -6.268864
# 64  -6.269066
# 15  -6.268147
# 1   -6.268377
# 46  -6.251014
# 24  -6.267895
# 41  -6.251253
# 39  -6.266350
# 17  -6.265295
# 10  -6.270379
# 11  -6.267517
# 21  -6.256907
# 19  -6.270176
# 9   -6.261596
# 16  -6.263233
# 31  -6.262080
# 22  -6.251619
# 25  -6.263038
# 20  -6.263142
# 12  -6.248131
# 48  -6.259724
# 18  -6.268804
# 7   -6.257917
# 71  -6.256618
# 67  -6.256548
# 54  -6.265348
# 26  -6.262833
# 28  -6.261248
# 42  -6.254019
# 32  -6.260037
# 29  -6.260499
# 47  -6.267362
# 50  -6.258760
# 36  -6.264264
# 13  -6.258772
# 52  -6.263057
# 43  -6.258639
# 73  -6.252528
# 56  -6.258591
# 74  -6.278650
# 61  -6.256014
# 38  -6.278976
# 40  -6.250451
# 62  -6.266099
# 30  -6.259160
# 60  -6.273178
# 45  -6.271894
# 82  -6.280011
# 66  -6.253020
# 53  -6.250525
# 72  -6.241793
# 49  -6.281092
# 95  -6.273386
# 80  -6.265517
# 79  -6.281938
# 97  -6.258335
# 65  -6.239204
# 77  -6.239015
# 58  -6.261059
# 59  -6.283990
# 70  -6.238462
# 55  -6.239362
# 87  -6.237792
# 69  -6.263247
# 63  -6.242132
# 75  -6.263497
# 68  -6.272902
# 57  -6.265131
# 93  -6.265129
# 91  -6.265482
# 84  -6.274447
# 88  -6.286734
# 90  -6.286831
# 76  -6.272624
# 89  -6.268992
# 81  -6.264569
# 78  -6.273716
# 86  -6.275473
# 83  -6.234691
# 85  -6.234223
# 92  -6.233529
# 98  -6.268704
# 96  -6.235269
# 94  -6.254795
# 99  -6.264804

# %% [markdown]
# ###CHECKING: Missing Value

# %%
data.isna().sum()
# Out:
# Name          0
# Categories    0
# Distance      0
# Address       2
# City          4
# Latitude      0
# Longitude     0
# dtype: int64

# %%
data = data.dropna()
data.isna().sum()
# Out:
# Name          0
# Categories    0
# Distance      0
# Address       0
# City          0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
data.iloc[82,:]
# Out:
# Name                   57 The Headline
# Categories                         Pub
# Distance                          2177
# Address       56-57 Lwr Clanbrassil St
# City                          Dublin 8
# Latitude                       53.3324
# Longitude                     -6.27547
# Name: 86, dtype: object

# %% [markdown]
# ##FOLIUM: Mapping RESTAURANTS in Connaught Place, Delhi, India

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(data.Latitude, data.Longitude):
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(data.Latitude)
longitudes = list(data.Longitude)
labels = list(data.Name)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(Map)    
    
# add incidents to map
Map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #AMADEUS API

# %% [markdown]
# >AMADEUS API

# %%
# !pip install zomathon
# Out:
# Collecting zomathon
#   Downloading https://files.pythonhosted.org/packages/c6/d1/abef6997f5cfc638e6a673093897974f2b7eda3c704a253e0b7a5de96abf/zomathon-1.4.tar.gz
# Building wheels for collected packages: zomathon
#   Building wheel for zomathon (setup.py) ... done
#   Created wheel for zomathon: filename=zomathon-1.4-cp36-none-any.whl size=4003 sha256=1c2cbe92eebb54c0624ffa2fb6d6c682de835ff144c0cbdfd6ce3e35679d6de8
#   Stored in directory: /root/.cache/pip/wheels/9f/e6/99/fcf780087e587cbe330fad7e2972f8ec1adc88b0ab4e60d1b0
# Successfully built zomathon
# Installing collected packages: zomathon
# Successfully installed zomathon-1.4

# %%
import requests

url = "https://ip-geolocation-ipwhois-io.p.rapidapi.com/json/"

headers = {
    'x-rapidapi-host': "EH5PvtH0FhmjNG7wxZLYyJ7cKOVCYcY1",
    'x-rapidapi-key': "EsG5zQaSesFDRiib"
    }

response = requests.request("GET", url, headers=headers)

#print(response.text)
print(requests.request("GET", url, headers=headers).json())
#{"ip":"255.255.0.255","success":true,"type":"IPv4","continent":"Asia","continent_code":"AS","country":"Malaysia","country_code":"MY","country_flag":"https:\/\/cdn.ipwhois.io\/flags\/my.svg","country_capital":"Kuala Lumpur","country_phone":"+60","country_neighbours":"BN,TH,ID","region":"Selangor","city":"Klang","latitude":"3.044917","longitude":"101.4455621","asn":"AS55720","org":null,"isp":null,"timezone":"Asia\/Kuala_Lumpur","timezone_name":"Malaysia Time","timezone_dstOffset":"0","timezone_gmtOffset":"28800","timezone_gmt":"GMT +8:00","currency":"Malaysian Ringgit","currency_code":"MYR","currency_symbol":"RM","currency_rates":"4.1655","currency_plural":"Malaysian ringgits","completed_requests":0}

# %% [markdown]
# #ZOMATO API

# %% [markdown]
# >ZOMATO API

# %% [markdown]
# ###Declaring LISTS

# %% [markdown]
# >Declaring LISTS

# %%
Delivery = []
Takeaway = []
AverageCostof2 = []
Cuisines = []
Url = []
Image = []
Highlights = []
Address = []
Latitude = []
Longitude = []
Name = []
Type = []      
Contact = []
Timings = []
Rating = []
Review = []

# %% [markdown]
# ###DATA Extraction from ZOMATO API

# %%
headers = {'user-key': '2519d5963a6ce0e5bccf4a5f9d9e190b'}
for index, row in tqdm(data.iterrows()):
  try:
    print("Fetching data for venue: {}".format(index + 1))
    url = ('https://developers.zomato.com/api/v2.1/search?q={}&start=0&count=1&lat={}&lon={}&sort=real_distance').format(row['Name'], row['Latitude'], row['Longitude'])
    result = requests.get(url, headers = headers).json()
    Delivery.append(result['restaurants'][0]['restaurant']['R']['has_menu_status']['delivery']) #Delivery
    Takeaway.append(result['restaurants'][0]['restaurant']['R']['has_menu_status']['takeaway'])#Takeaway
    AverageCostof2.append(result['restaurants'][0]['restaurant']['average_cost_for_two']) #Average Cost of 2
    Cuisines.append(result['restaurants'][0]['restaurant']['cuisines'])
    Url.append(result['restaurants'][0]['restaurant']['events_url'])
    Image.append(result['restaurants'][0]['restaurant']['featured_image'])
    Highlights.append(result['restaurants'][0]['restaurant']['highlights'])
    Address.append(result['restaurants'][0]['restaurant']['location']['address'])
    Latitude.append(result['restaurants'][0]['restaurant']['location']['latitude'])
    Longitude.append(result['restaurants'][0]['restaurant']['location']['longitude'])
    Name.append(result['restaurants'][0]['restaurant']['name']) #Name
    Type.append(result['restaurants'][0]['restaurant']['establishment']) #Restaurant Type
    Contact.append(result['restaurants'][0]['restaurant']['phone_numbers']) #Contact
    Timings.append(result['restaurants'][0]['restaurant']['timings']) #Time
    Rating.append(result['restaurants'][0]['restaurant']['user_rating']['rating_obj']['title']['text']) #Rating
    Review.append(result['restaurants'][0]['restaurant']['user_rating']['rating_text']) #Rating
  except:
    print('Error')
    print(result)
    continue
# Out:
# 0it [00:00, ?it/s]
# Fetching data for venue: 1
# 1it [00:00,  1.63it/s]
# Fetching data for venue: 2
# 2it [00:01,  1.59it/s]
# Fetching data for venue: 3
# 3it [00:02,  1.43it/s]
# Fetching data for venue: 4
# 4it [00:02,  1.46it/s]
# Fetching data for venue: 5
# 5it [00:03,  1.28it/s]
# Fetching data for venue: 6
# 6it [00:04,  1.37it/s]
# Fetching data for venue: 7
# 7it [00:04,  1.46it/s]
# Fetching data for venue: 8
# 8it [00:05,  1.43it/s]
# Fetching data for venue: 9
# 9it [00:06,  1.56it/s]
# Fetching data for venue: 10
# 10it [00:07,  1.36it/s]
# Fetching data for venue: 11
# 11it [00:07,  1.44it/s]
# Fetching data for venue: 12
# 12it [00:08,  1.44it/s]
# Fetching data for venue: 13
# 13it [00:08,  1.56it/s]
# Fetching data for venue: 14
# 14it [00:09,  1.71it/s]
# Fetching data for venue: 15
# 15it [00:09,  1.77it/s]
# Fetching data for venue: 16
# 16it [00:10,  1.67it/s]
# Fetching data for venue: 17
# 17it [00:11,  1.23it/s]
# Fetching data for venue: 18
# 18it [00:12,  1.27it/s]
# Fetching data for venue: 19
# 19it [00:13,  1.43it/s]
# Error
# {'results_found': 0, 'results_start': 0, 'results_shown': 0, 'restaurants': []}
# Fetching data for venue: 20
# 20it [00:13,  1.38it/s]
# Fetching data for venue: 21
# 21it [00:14,  1.47it/s]
# Fetching data for venue: 22
# 22it [00:15,  1.33it/s]
# Fetching data for venue: 23
# 23it [00:16,  1.45it/s]
# Fetching data for venue: 24
# 24it [00:16,  1.47it/s]
# Fetching data for venue: 25
# 25it [00:17,  1.58it/s]
# Error
# {'results_found': 0, 'results_start': 0, 'results_shown': 0, 'restaurants': []}
# Fetching data for venue: 26
# 26it [00:17,  1.75it/s]
# Fetching data for venue: 27
# 27it [00:18,  1.61it/s]
# Fetching data for venue: 28
# 28it [00:19,  1.58it/s]
# Fetching data for venue: 29
# 29it [00:19,  1.65it/s]
# Fetching data for venue: 30
# 30it [00:20,  1.62it/s]
# Fetching data for venue: 31
# 31it [00:20,  1.77it/s]
# Fetching data for venue: 32
# 32it [00:21,  1.55it/s]
# Fetching data for venue: 33
# 33it [00:22,  1.55it/s]
# Fetching data for venue: 34
# 34it [00:22,  1.58it/s]
# Fetching data for venue: 35
# 35it [00:23,  1.69it/s]
# Fetching data for venue: 36
# 36it [00:25,  1.14s/it]
# Fetching data for venue: 37
# 37it [00:26,  1.01s/it]
# Fetching data for venue: 38
# 38it [00:27,  1.11it/s]
# Fetching data for venue: 39
# 39it [00:27,  1.18it/s]
# Fetching data for venue: 40
# 40it [00:28,  1.24it/s]
# Fetching data for venue: 41
# 41it [00:29,  1.29it/s]
# Fetching data for venue: 42
# 42it [00:29,  1.41it/s]
# Fetching data for venue: 43
# 43it [00:30,  1.26it/s]
# Fetching data for venue: 44
# 44it [00:31,  1.30it/s]
# Fetching data for venue: 45
# 45it [00:31,  1.42it/s]
# Fetching data for venue: 46
# 46it [00:32,  1.35it/s]
# Fetching data for venue: 47
# 47it [00:33,  1.52it/s]
# Fetching data for venue: 48
# 48it [00:33,  1.53it/s]
# Fetching data for venue: 49
# 49it [00:35,  1.24it/s]
# Fetching data for venue: 50
# 50it [00:36,  1.16it/s]
# Fetching data for venue: 51
# 51it [00:36,  1.32it/s]
# Fetching data for venue: 52
# 52it [00:37,  1.41it/s]
# Fetching data for venue: 53
# 53it [00:37,  1.60it/s]
# Fetching data for venue: 54
# 54it [00:38,  1.56it/s]
# Fetching data for venue: 55
# 55it [00:38,  1.64it/s]
# Fetching data for venue: 56
# 56it [00:39,  1.35it/s]
# Fetching data for venue: 57
# 57it [00:40,  1.43it/s]
# Fetching data for venue: 58
# 58it [00:40,  1.57it/s]
# Fetching data for venue: 59
# 59it [00:41,  1.58it/s]
# Fetching data for venue: 60
# 60it [00:43,  1.14it/s]
# Fetching data for venue: 61
# 61it [00:43,  1.32it/s]
# Fetching data for venue: 62
# 62it [00:44,  1.41it/s]
# Fetching data for venue: 63
# 63it [00:44,  1.44it/s]
# Fetching data for venue: 64
# 64it [00:45,  1.59it/s]
# Fetching data for venue: 65
# 65it [00:45,  1.58it/s]
# Fetching data for venue: 66
# 66it [00:46,  1.37it/s]
# Fetching data for venue: 67
# 67it [00:47,  1.56it/s]
# Error
# {'results_found': 0, 'results_start': 0, 'results_shown': 0, 'restaurants': []}
# Fetching data for venue: 68
# 68it [00:47,  1.57it/s]
# Fetching data for venue: 69
# 69it [00:48,  1.51it/s]
# Fetching data for venue: 70
# 70it [00:49,  1.62it/s]
# Fetching data for venue: 71
# 71it [00:49,  1.75it/s]
# Fetching data for venue: 72
# 72it [00:50,  1.83it/s]
# Fetching data for venue: 73
# 73it [00:50,  1.73it/s]
# Fetching data for venue: 74
# 74it [00:51,  1.63it/s]
# Fetching data for venue: 75
# 75it [00:52,  1.66it/s]
# Fetching data for venue: 76
# 76it [00:52,  1.77it/s]
# Fetching data for venue: 77
# 77it [00:52,  1.83it/s]
# Fetching data for venue: 78
# 78it [00:53,  1.78it/s]
# Fetching data for venue: 79
# 79it [00:54,  1.65it/s]
# Fetching data for venue: 80
# 80it [00:54,  1.68it/s]
# Fetching data for venue: 81
# 81it [00:55,  1.74it/s]
# Fetching data for venue: 82
# 82it [00:55,  1.78it/s]
# Fetching data for venue: 83
# 83it [00:56,  1.68it/s]
# Fetching data for venue: 84
# 84it [00:57,  1.72it/s]
# Fetching data for venue: 85
# 85it [00:57,  1.59it/s]
# Fetching data for venue: 86
# 86it [00:58,  1.82it/s]
# Fetching data for venue: 87
# 87it [00:59,  1.31it/s]
# Fetching data for venue: 88
# 88it [01:00,  1.40it/s]
# Fetching data for venue: 89
# 89it [01:00,  1.38it/s]
# Fetching data for venue: 90
# 90it [01:01,  1.46it/s]
# Fetching data for venue: 91
# 91it [01:02,  1.52it/s]
# Fetching data for venue: 92
# 92it [01:02,  1.57it/s]
# Fetching data for venue: 93
# 93it [01:03,  1.62it/s]
# Fetching data for venue: 94
# 94it [01:03,  1.67it/s]
# Fetching data for venue: 95
# 95it [01:04,  1.65it/s]
# Fetching data for venue: 96
# 96it [01:04,  1.79it/s]
# Fetching data for venue: 97
# 97it [01:06,  1.32it/s]
# Fetching data for venue: 98
# 98it [01:06,  1.38it/s]
# Fetching data for venue: 99
# 99it [01:07,  1.50it/s]
# Fetching data for venue: 100
# 100it [01:07,  1.47it/s]

# %%
"""result['restaurants'][0]['restaurant']['R']['has_menu_status']['delivery'])#Delivery
result['restaurants'][0]['restaurant']['R']['has_menu_status']['takeaway']) #Takeaway
result['restaurants'][0]['restaurant']['average_cost_for_two'] #Average Cost of 2
result['restaurants'][0]['restaurant']['cuisines']
result['restaurants'][0]['restaurant']['events_url']
result['restaurants'][0]['restaurant']['featured_image']
result['restaurants'][0]['restaurant']['highlights']
result['restaurants'][0]['restaurant']['location']['address']
result['restaurants'][0]['restaurant']['location']['latitude']
result['restaurants'][0]['restaurant']['location']['longitude']
result['restaurants'][0]['restaurant']['name'] #Name
result['restaurants'][0]['restaurant']['establishment'] #Restaurant Type
result['restaurants'][0]['restaurant']['phone_numbers'] #Contact
result['restaurants'][0]['restaurant']['timings'] #Time
result['restaurants'][0]['restaurant']['user_rating']['rating_obj']['title']['text'] #Rating
result['restaurants'][0]['restaurant']['user_rating']['rating_text'] #Rating"""
# Out:
# "result['restaurants'][0]['restaurant']['R']['has_menu_status']['delivery'])#Delivery\nresult['restaurants'][0]['restaurant']['R']['has_menu_status']['takeaway']) #Takeaway\nresult['restaurants'][0]['restaurant']['average_cost_for_two'] #Average Cost of 2\nresult['restaurants'][0]['restaurant']['cuisines']\nresult['restaurants'][0]['restaurant']['events_url']\nresult['restaurants'][0]['restaurant']['featured_image']\nresult['restaurants'][0]['restaurant']['highlights']\nresult['restaurants'][0]['restaurant']['location']['address']\nresult['restaurants'][0]['restaurant']['location']['latitude']\nresult['restaurants'][0]['restaurant']['location']['longitude']\nresult['restaurants'][0]['restaurant']['name'] #Name\nresult['restaurants'][0]['restaurant']['establishment'] #Restaurant Type\nresult['restaurants'][0]['restaurant']['phone_numbers'] #Contact\nresult['restaurants'][0]['restaurant']['timings'] #Time\nresult['restaurants'][0]['restaurant']['user_rating']['rating_obj']['title']['text'] #Rating\nresult['restaurants'][0]['restaurant']['user_rating']['rating_text'] #Rating"

# %% [markdown]
# >DATA Extraction from ZOMATO API

# %% [markdown]
# ###Creating RESTAURANTS DataFrame

# %%
RESTAURANTS = pd.DataFrame({'Delivery':Delivery,
'Takeaway':Takeaway,
'Average Cost of 2':AverageCostof2,
'Cousines':Cuisines,
'URL':Url,
'Image':Image,
#'Highlights':Highlights,
'Address':Address,
'Latitude':Latitude,
'Longitude':Longitude,
'Name':Name,
'Type':Type,      
'Contact':Contact,
'Timings':Timings,
'Rating':Rating,
'Review':Review})

# %% [markdown]
# >Creating RESTAURANTS DataFrame

# %% [markdown]
# ###Data Pre-Processing

# %% [markdown]
# >Data Pre-Processing

# %%
RESTAURANTS = RESTAURANTS[['Name', 'Type', 'Rating', 'Review', 'Timings', 'Cousines', 'Average Cost of 2','Address', 'Latitude', 'Longitude', 'Image', 'URL', 'Delivery', 'Takeaway', 'Contact']]
RESTAURANTS['Type'] = RESTAURANTS['Type'].apply(lambda x: ''.join(x))
RESTAURANTS = RESTAURANTS[RESTAURANTS['Rating'] != '-']
RESTAURANTS = RESTAURANTS.drop([8, 24, 75]) #63
RESTAURANTS.head()
# Out:
#                                          Name             Type Rating  \
# 0  Nostalgia at 1911 Brasserie - The Imperial      Fine Dining    3.5
# 1                           Natural Ice Cream  Dessert Parlour    4.7
# 2                             Cafe Coffee Day             Café    2.6
# 3                             Peshawari Dhaba                     3.9
# 4           Tamra - Shangri-La's - Eros Hotel      Fine Dining    4.5
#
#       Review                        Timings  \
# 0       Good            6:30 PM to 11:45 PM
# 1  Excellent            9am – 1am (Mon-Sun)
# 2    Average                  8 AM to 11 PM
# 3       Good  12 Noon to 4 PM, 6 PM to 8 PM
# 4  Excellent            7 AM to 12 Midnight
#
#                                             Cousines  Average Cost of 2  \
# 0                              European, Continental               6000
# 1                                Desserts, Ice Cream                350
# 2     Cafe, Fast Food, Desserts, Beverages, Sandwich                500
# 3                                       North Indian                150
# 4  North Indian, Continental, European, Asian, Am...               3800
#
#                                              Address       Latitude  \
# 0                   The Imperial, Janpath, New Delhi  28.6250329807
# 1  L-8, L Block, Outer Circle, Connaught Place, N...  28.6344491660
# 2  Gate 7, Rajiv Chowk Metro Station, Connaught P...  28.6329745678
# 3      S-5, Palika Bazar, Connaught Place, New Delhi  28.6307183424
# 4  Shangri-La's - Eros Hotel, 19, Level 1, Ashoka...  28.6211052250
#
#        Longitude                                              Image  \
# 0  77.2190765664
# 1  77.2220343724  https://b.zmtcdn.com/data/pictures/8/313368/da...
# 2  77.2197072208  https://b.zmtcdn.com/data/pictures/chains/3/59...
# 3  77.2172660753
# 4  77.2169569507  https://b.zmtcdn.com/data/pictures/9/311369/1d...
#
#                                                  URL  Delivery  Takeaway  \
# 0  https://www.zomato.com/ncr/nostalgia-at-1911-b...        -1        -1
# 1  https://www.zomato.com/NaturalsCP/events#tabto...        -1        -1
# 2  https://www.zomato.com/ncr/cafe-coffee-day-15-...        -1        -1
# 3  https://www.zomato.com/ncr/peshawari-dhaba-con...        -1        -1
# 4  https://www.zomato.com/ncr/tamra-shangri-las-e...        -1        -1
#
#                                       Contact
# 0                  011 41116602, 011 41116603
# 1                011 43785502, +91 8368436163
# 2                              +91 9999344535
# 3                                011 66724302
# 4  011 41191010, 011 41191011, +91 9599787836

# %%
RESTAURANTS.groupby('Type').count()
# Out:
#                  Name  Rating  Review  Timings  Cousines  Average Cost of 2  \
# Type
#                     3       3       3        3         3                  3
# Bakery              2       2       2        2         2                  2
# Bar                 6       6       6        6         6                  6
# Café               14      14      14       14        14                 14
# Casual Dining      16      16      16       16        16                 16
# Club                1       1       1        1         1                  1
# Dessert Parlour     2       2       2        2         2                  2
# Fine Dining        13      13      13       13        13                 13
# Lounge              3       3       3        3         3                  3
# Paan Shop           3       3       3        3         3                  3
# Quick Bites        17      17      17       17        17                 17
# Sweet Shop          4       4       4        4         4                  4
#
#                  Address  Latitude  Longitude  Image  URL  Delivery  Takeaway  \
# Type
#                        3         3          3      3    3         3         3
# Bakery                 2         2          2      2    2         2         2
# Bar                    6         6          6      6    6         6         6
# Café                  14        14         14     14   14        14        14
# Casual Dining         16        16         16     16   16        16        16
# Club                   1         1          1      1    1         1         1
# Dessert Parlour        2         2          2      2    2         2         2
# Fine Dining           13        13         13     13   13        13        13
# Lounge                 3         3          3      3    3         3         3
# Paan Shop              3         3          3      3    3         3         3
# Quick Bites           17        17         17     17   17        17        17
# Sweet Shop             4         4          4      4    4         4         4
#
#                  Contact
# Type
#                        3
# Bakery                 2
# Bar                    6
# Café                  14
# Casual Dining         16
# Club                   1
# Dessert Parlour        2
# Fine Dining           13
# Lounge                 3
# Paan Shop              3
# Quick Bites           17
# Sweet Shop             4

# %%
print('There are {} uniques categories.'.format(len(RESTAURANTS['Type'].unique())))

# %%
# one hot encoding
RESTAURANTS_onehot = pd.get_dummies(RESTAURANTS[['Type']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
RESTAURANTS_onehot['Name'] = RESTAURANTS['Name'] 

# move neighborhood column to the first column
fixed_columns = [RESTAURANTS_onehot.columns[-1]] + list(RESTAURANTS_onehot.columns[:-1])
RESTAURANTS_onehot = RESTAURANTS_onehot[fixed_columns]

RESTAURANTS_onehot

# %%
RESTAURANTS_onehot.shape

# %%
RESTAURANTS_grouped = RESTAURANTS_onehot.groupby('Name').mean().reset_index()
RESTAURANTS_grouped

# %%
RESTAURANTS_grouped.shape

# %% [markdown]
# ##GROUPING DATA

# %% [markdown]
# >GROUPING DATA

# %% [markdown]
# ###Area wise GROUPING Data

# %% [markdown]
# >Area wise GROUPING Data

# %%
num_top_venues = 10

for hood in RESTAURANTS_grouped['Name']:
    print("----"+hood+"----")
    temp = RESTAURANTS_grouped[RESTAURANTS_grouped['Name'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

# %% [markdown]
# > FUNCTION: Returning popular venues

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ###TOP Common Venues

# %% [markdown]
# >TOP Common Venues

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Name']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
RESTAURANTS_venues_sorted = pd.DataFrame(columns=columns)
RESTAURANTS_venues_sorted['Name'] = RESTAURANTS_grouped['Name']

for ind in np.arange(RESTAURANTS_grouped.shape[0]):
    RESTAURANTS_venues_sorted.iloc[ind, 1:] = return_most_common_venues(RESTAURANTS_grouped.iloc[ind, :], num_top_venues)

RESTAURANTS_venues_sorted.head()

# %% [markdown]
# ##Clustering RESTAURANTS by KMEANS

# %% [markdown]
# > Run *k*-means to cluster the restaurants into 5 clusters.

# %%
# set number of clusters
kclusters = 5

RESTAURANTS_grouped_clustering = RESTAURANTS_grouped.drop('Name', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(RESTAURANTS_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

# %% [markdown]
# > Let's create a new dataframe that includes the cluster as well as the top 10 venues for each restaurants.

# %%
# add clustering labels
RESTAURANTS_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

RESTAURANTS_merged = RESTAURANTS
#RESTAURANTS_merged.drop(['Timing', 'Cosuines', 'Image', 'URL', 'Delivery', 'Takeaway'], axis = 1, inplace = True)
# merge RESTAURANTS_grouped with RESTAURANTS_data to add latitude/longitude for each neighborhood
RESTAURANTS_merged = RESTAURANTS_merged.join(RESTAURANTS_venues_sorted.set_index('Name'), on='Name')

RESTAURANTS_merged.head() # check the last columns!

# %%
#RESTAURANTS_merged = RESTAURANTS_merged.drop(16)
#RESTAURANTS_merged

# %%
RESTAURANTS_merged['Cluster Labels'] = RESTAURANTS_merged['Cluster Labels'].astype(int)
RESTAURANTS_merged.head()

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# > Finally, let's visualize the resulting clusters

# %%
incidents = folium.map.FeatureGroup()

world_map = folium.Map(location=[latitude, longitude], zoom_start=11, tiles='Stamen Terrain')
# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(RESTAURANTS.Latitude, RESTAURANTS.Longitude):
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6,
            legend_name='COVID'
        )
        
    )

# add incidents to map
world_map.add_child(incidents)

# %%
#create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(RESTAURANTS_merged['Latitude'], RESTAURANTS_merged['Longitude'], RESTAURANTS_merged['Name'], RESTAURANTS_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters

# %%
incidents = folium.map.FeatureGroup()

world_map = folium.Map(location=[latitude, longitude], zoom_start=2, tiles='Stamen Terrain')
# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(RESTAURANTS.Latitude, RESTAURANTS.Longitude):
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6,
            legend_name='COVID'
        )
    )

# add incidents to map
world_map.add_child(incidents)

# %%
#RESTAURANTS['Type'].value_counts().plot.bar()

# %% [markdown]
# ###BARGraph: Plotting the count of TYPE of RESTAURANTS

# %% [markdown]
# >BARGraph: Plotting the count of TYPE of RESTAURANTS

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
Distribution = RESTAURANTS['Type'].value_counts()
colors = cm.rainbow(np.linspace(0, 1, len(Distribution.index)))
plt.figure(figsize = (10, 10))
plt.xticks(rotation = 90)
plt.xlabel("Restaurant Types", fontsize = 16)
plt.ylabel("Count", fontsize = 16)
plt.title("Count of Restaurants Types", fontsize = 16)
plt.bar(Distribution.index, Distribution.values, color = colors)

# %% [markdown]
# ###OVERLAPPING BARGraph: Plotting the RATING of RESTAURANTS

# %% [markdown]
# >OVERLAPPING BARGraph: Plotting the RATING of RESTAURANTS

# %%
RESTAURANTS['Rating'] = RESTAURANTS['Rating'].astype(float)
rating = RESTAURANTS['Rating'].value_counts().sort_index()
plt.figure(figsize = (10, 10))
plt.bar(rating.index, rating.values, color = cm.rainbow(np.linspace(0, 1, len(rating.index))))
plt.xlabel("Rating", fontsize = 16)
plt.ylabel("Count", fontsize = 16)
plt.title("Count of venues with given rating", fontsize = 16)

# %% [markdown]
# >SETTING Recursion LIMIT

# %%
sys.setrecursionlimit(15000)

# %% [markdown]
# ###FOLIUM: Mapping

# %% [markdown]
# >FOLIUM: Mapping

# %%
Map = folium.Map(location = [latitude, longitude], zoom_start = 10, tiles = 'Stamen Terrain')

Marker = folium.map.FeatureGroup()

Marker.add_child(folium.CircleMarker([latitude, longitude], 
                                             radius = 5, 
                                             color = 'red', 
                                             fill_color = 'Red'))
Map.add_child(Marker)
folium.Marker([latitude, longitude], popup = 'Connaught Place').add_to(Map)
Map

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(RESTAURANTS.Latitude, RESTAURANTS.Longitude):
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(RESTAURANTS.Latitude)
longitudes = list(RESTAURANTS.Longitude)
labels = list(RESTAURANTS.Name)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(Map)    
    
# add incidents to map
Map.add_child(incidents)

# %%
"""import requests

url = "https://ip-geolocation-ipwhois-io.p.rapidapi.com/json/"

payload = "{}"
headers = {
    'x-rapidapi-host': "ip-geolocation-ipwhois-io.p.rapidapi.com",
    'x-rapidapi-key': "{{c8f4197351msh6be67efb0ec4cedp168cdejsnd132e8183b65}}"
}
params = {

}

response = requests.get(url).json() #requests.request("GET", url, data=payload, headers=headers, params=params)

print(response)"""

# %%
# !pip install urllib3

# %%
"""import urllib3
import json

ip = "8.8.4.4";

# Sending an API request
http = urllib3.PoolManager()
response = http.request('GET', "http://ipwhois.app/json/"+ip)
response.headers.keys()
#ipgeolocation = json.load(response)

# Country code output, field "country_code"
#print =(ipgeolocation["country_code"])"""

# %%
"""import requests

url = "https://datascience1.p.rapidapi.com/"


headers = {
    'x-rapidapi-host': "datascience1.p.rapidapi.com",
    'x-rapidapi-key': "c8f4197351msh6be67efb0ec4cedp168cdejsnd132e8183b65",
    'content-type': "application/x-www-form-urlencoded"
    }

response = requests.request('GET', url, data=payload, headers=headers)

print(response.text)"""

# %% [markdown]
# ##Clustering RESTAURANTS by Distance

# %% [markdown]
# > Run *k*-means to cluster the restaurants into 5 clusters.

# %%
# set number of clusters
kclusters = 5

RESTAURANTS_grouped_clustering = RESTAURANTS_grouped.drop('Name', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(RESTAURANTS_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

# %% [markdown]
# > Let's create a new dataframe that includes the cluster as well as the top 10 venues for each restaurants.

# %%
# add clustering labels
RESTAURANTS_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

RESTAURANTS_merged = RESTAURANTS
#RESTAURANTS_merged.drop(['Timing', 'Cosuines', 'Image', 'URL', 'Delivery', 'Takeaway'], axis = 1, inplace = True)
# merge RESTAURANTS_grouped with RESTAURANTS_data to add latitude/longitude for each neighborhood
RESTAURANTS_merged = RESTAURANTS_merged.join(RESTAURANTS_venues_sorted.set_index('Name'), on='Name')

RESTAURANTS_merged.head() # check the last columns!

# %%
#RESTAURANTS_merged = RESTAURANTS_merged.drop(16)
#RESTAURANTS_merged

# %%
RESTAURANTS_merged['Cluster Labels'] = RESTAURANTS_merged['Cluster Labels'].astype(int)
RESTAURANTS_merged.head()

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# > Finally, let's visualize the resulting clusters

# %%
"""# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(RESTAURANTS_merged['Latitude'], RESTAURANTS_merged['Longitude'], RESTAURANTS_merged['Name'], RESTAURANTS_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters"""

# %%
#RESTAURANTS['Type'].value_counts().plot.bar()

# %% [markdown]
# ###BARGraph: Plotting the count of TYPE of RESTAURANTS

# %% [markdown]
# >BARGraph: Plotting the count of TYPE of RESTAURANTS

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
Distribution = RESTAURANTS['Type'].value_counts()
colors = cm.rainbow(np.linspace(0, 1, len(Distribution.index)))
plt.figure(figsize = (10, 10))
plt.xticks(rotation = 90)
plt.xlabel("Restaurant Types", fontsize = 16)
plt.ylabel("Count", fontsize = 16)
plt.title("Count of Restaurants Types", fontsize = 16)
plt.bar(Distribution.index, Distribution.values, color = colors)

# %% [markdown]
# ###OVERLAPPING BARGraph: Plotting the RATING of RESTAURANTS

# %% [markdown]
# >OVERLAPPING BARGraph: Plotting the RATING of RESTAURANTS

# %%
RESTAURANTS['Rating'] = RESTAURANTS['Rating'].astype(float)
rating = RESTAURANTS['Rating'].value_counts().sort_index()
plt.figure(figsize = (10, 10))
plt.bar(rating.index, rating.values, color = cm.rainbow(np.linspace(0, 1, len(rating.index))))
plt.xlabel("Rating", fontsize = 16)
plt.ylabel("Count", fontsize = 16)
plt.title("Count of venues with given rating", fontsize = 16)

# %% [markdown]
# >SETTING Recursion LIMIT

# %%
sys.setrecursionlimit(15000)

# %% [markdown]
# ###FOLIUM: Mapping

# %% [markdown]
# >FOLIUM: Mapping

# %%
Map = folium.Map(location = [latitude, longitude], zoom_start = 10, tiles = 'Stamen Terrain')

Marker = folium.map.FeatureGroup()

Marker.add_child(folium.CircleMarker([latitude, longitude], 
                                             radius = 5, 
                                             color = 'red', 
                                             fill_color = 'Red'))
Map.add_child(Marker)
folium.Marker([latitude, longitude], popup = 'Connaught Place').add_to(Map)
Map

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(RESTAURANTS.Latitude, RESTAURANTS.Longitude):
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(RESTAURANTS.Latitude)
longitudes = list(RESTAURANTS.Longitude)
labels = list(RESTAURANTS.Name)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(Map)    
    
# add incidents to map
Map.add_child(incidents)

# %%
"""import requests

url = "https://ip-geolocation-ipwhois-io.p.rapidapi.com/json/"

payload = "{}"
headers = {
    'x-rapidapi-host': "ip-geolocation-ipwhois-io.p.rapidapi.com",
    'x-rapidapi-key': "{{c8f4197351msh6be67efb0ec4cedp168cdejsnd132e8183b65}}"
}
params = {

}

response = requests.get(url).json() #requests.request("GET", url, data=payload, headers=headers, params=params)

print(response)"""

# %%
# !pip install urllib3

# %%
"""import urllib3
import json

ip = "8.8.4.4";

# Sending an API request
http = urllib3.PoolManager()
response = http.request('GET', "http://ipwhois.app/json/"+ip)
response.headers.keys()
#ipgeolocation = json.load(response)

# Country code output, field "country_code"
#print =(ipgeolocation["country_code"])"""

# %%
"""import requests

url = "https://datascience1.p.rapidapi.com/"


headers = {
    'x-rapidapi-host': "datascience1.p.rapidapi.com",
    'x-rapidapi-key': "c8f4197351msh6be67efb0ec4cedp168cdejsnd132e8183b65",
    'content-type': "application/x-www-form-urlencoded"
    }

response = requests.request('GET', url, data=payload, headers=headers)

print(response.text)"""
